# %% [markdown]
# <a href="https://colab.research.google.com/github/MajidAlmadani/T5-test/blob/main/Task_(1)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
# import the important libraries that would use in the project
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('Task (1) Dataset.csv')

# To see the data values
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
## See what columns have missing values
display(df.isna().sum())

# I will handle the missing data in the following:
# The bigger number like above 2000 missing data I would drop the column *if* the column would result nothing in the predictor
# The rest would add a function to check another values in the same row and create a mode from the similar rows and add the most common value in the missing column
# There still few values cannot be generated from the custom function, and I would make it Unknown for future reference in analysis


##### Handling most of the missing values depend on the function that created before to count the null & missing values in the dataset
##### This method is explained above and it's easy to implement depend on each column
##### Cannot be used due to take a lot of time
# def handling_missing_values(row):
#   condition = (df['Sex_of_driver'] == row['Sex_of_driver']) & (df['Age_band_of_driver'] == row['Age_band_of_driver']) & (df['Day_of_week'] == row['Day_of_week']) & (df['Weather_conditions'] == row['Weather_conditions'])

#   selected_conditions = df[condition]

#   if len(selected_conditions) == 0:
#     return row
#   else:
#     print(row)
#     if selected_conditions['Educational_level'].mode().empty: row['Educational_level'] = 'Unknown'
#     else: row['Educational_level'] = selected_conditions['Educational_level'].mode()[0]

#     if selected_conditions['Vehicle_driver_relation'].mode().empty: row['Vehicle_driver_relation'] = 'Unknown'
#     else: row['Vehicle_driver_relation'] = selected_conditions['Vehicle_driver_relation'].mode()[0]

#     if selected_conditions['Driving_experience'].mode().empty: row['Driving_experience'] = 'Unknown'
#     else: row['Driving_experience'] = selected_conditions['Driving_experience'].mode()[0]

#     if selected_conditions['Type_of_vehicle'].mode().empty: row['Type_of_vehicle'] = 'Unknown'
#     else: row['Type_of_vehicle'] = selected_conditions['Type_of_vehicle'].mode()[0]

#     if selected_conditions['Owner_of_vehicle'].mode().empty: row['Owner_of_vehicle'] = 'Unknown'
#     else: row['Owner_of_vehicle'] = selected_conditions['Owner_of_vehicle'].mode()[0]

#     if selected_conditions['Area_accident_occured'].mode().empty: row['Area_accident_occured'] = 'Unknown'
#     else: row['Area_accident_occured'] = selected_conditions['Area_accident_occured'].mode()[0]

#     if selected_conditions['Lanes_or_Medians'].mode().empty: row['Lanes_or_Medians'] = 'Unknown'
#     else: row['Lanes_or_Medians'] = selected_conditions['Lanes_or_Medians'].mode()[0]

#     if selected_conditions['Road_allignment'].mode().empty: row['Road_allignment'] = 'Unknown'
#     else: row['Road_allignment'] = selected_conditions['Road_allignment'].mode()[0]

#     if selected_conditions['Road_surface_type'].mode().empty: row['Road_surface_type'] = 'Unknown'
#     else: row['Road_surface_type'] = selected_conditions['Road_surface_type'].mode()[0]

#     if selected_conditions['Types_of_Junction'].mode().empty: row['Types_of_Junction'] = 'Unknown'
#     else: row['Types_of_Junction'] = selected_conditions['Types_of_Junction'].mode()[0]

#     if selected_conditions['Type_of_collision'].mode().empty: row['Type_of_collision'] = 'Unknown'
#     else: row['Type_of_collision'] = selected_conditions['Type_of_collision'].mode()[0]

#     if selected_conditions['Vehicle_movement'].mode().empty: row['Vehicle_movement'] = 'Unknown'
#     else: row['Vehicle_movement'] = selected_conditions['Vehicle_movement'].mode()[0]

#     return row

#df = df.apply(handling_missing_values, axis=1)



# Dropped the columns that have more than 2000 missing values while putting in mind that the value of the columns itself wouldn't change the decision that would create in the end
# The decision to to make less accedints in the road and the columns doesn't effect the predictor that much in sense
df.drop(columns=['Service_year_of_vehicle','Defect_of_vehicle','Fitness_of_casuality','Work_of_casuality'], inplace=True)

# I choosed this way becuase it will take less time but it's not the most effecient way in terms of data analysis
# Using custom function for filling the missing data would be better but not faster
df['Educational_level'] = df['Educational_level'].fillna(df['Educational_level'].mode()[0])
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0])
df['Driving_experience'] = df['Driving_experience'].fillna(df['Driving_experience'].mode()[0])
df['Type_of_vehicle'] = df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0])
df['Owner_of_vehicle'] = df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0])
df['Area_accident_occured'] = df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0])
df['Lanes_or_Medians'] = df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0])
df['Road_allignment'] = df['Road_allignment'].fillna(df['Road_allignment'].mode()[0])
df['Types_of_Junction'] = df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0])
df['Road_surface_type'] = df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0])
df['Type_of_collision'] = df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0])
df['Vehicle_movement'] = df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0])
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
# Changing the numerical values to be around the mean and standard deviation to ease the reading and the visualization
from sklearn.preprocessing import StandardScaler

SS = StandardScaler()
df['Number_of_vehicles_involved'] = SS.fit_transform(df[['Number_of_vehicles_involved']])
df['Number_of_casualties'] = SS.fit_transform(df[['Number_of_casualties']])

# See the values of each *object* column and if there are any anomilies to change
# From the values I can see that column *Age_band_of_casualty* have a value *5* even though it has value of *Under 18*
for i in df.select_dtypes(include='object').columns:
  display(df[i].value_counts())
  print("-"*50)

df['Age_band_of_casualty'] = df['Age_band_of_casualty'].apply(lambda x: 'Under 18' if x == '5' else x)
# Out:
# Time
# 15:30:00    120
# 17:10:00    110
# 18:30:00    103
# 11:30:00     99
# 17:00:00     98
#            ...
# 19:04:00      1
# 20:36:00      1
# 22:54:00      1
# 21:03:00      1
# 2:47:00       1
# Name: count, Length: 1074, dtype: int64
# --------------------------------------------------
# Day_of_week
# Friday       2041
# Thursday     1851
# Wednesday    1840
# Tuesday      1770
# Monday       1681
# Saturday     1666
# Sunday       1467
# Name: count, dtype: int64
# --------------------------------------------------
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64
# --------------------------------------------------
# Sex_of_driver
# Male       11437
# Female       701
# Unknown      178
# Name: count, dtype: int64
# --------------------------------------------------
# Educational_level
# Junior high school    8360
# Elementary school     2163
# High school           1110
# ...

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
# before the change
display(df.info())

# From the info we can see that the time is an object data type and we want it datatime type

df['Time'] = pd.to_datetime(df['Time'])

# After the change
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            12316 non-null  object
#  5   Vehicle_driver_relation      12316 non-null  object
#  6   Driving_experience           12316 non-null  object
#  7   Type_of_vehicle              12316 non-null  object
#  8   Owner_of_vehicle             12316 non-null  object
#  9   Area_accident_occured        12316 non-null  object
#  10  Lanes_or_Medians             12316 non-null  object
#  11  Road_allignment              12316 non-null  object
#  12  Types_of_Junction            12316 non-null  object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
display(df.describe())

display(df.shape)
# Out:
#                                 Time  Number_of_vehicles_involved  \
# count                          12316                 1.231600e+04
# mean   2024-07-25 14:17:50.768106496                 6.461577e-17
# min              2024-07-25 00:01:00                -1.510942e+00
# 25%              2024-07-25 10:31:00                -5.906077e-02
# 50%              2024-07-25 15:10:00                -5.906077e-02
# 75%              2024-07-25 18:10:00                -5.906077e-02
# max              2024-07-25 23:59:00                 7.200344e+00
# std                              NaN                 1.000041e+00
#
#        Number_of_casualties
# count          1.231600e+04
# mean          -4.153871e-17
# min           -5.442639e-01
# 25%           -5.442639e-01
# 50%           -5.442639e-01
# 75%            4.486488e-01
# max            6.406125e+00
# std            1.000041e+00
# (12316, 28)

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
# we can see in the first table that most of the driving experience in 5-10 years even in normal weather conditions they would have the higher rate of accedints
display(df.groupby(['Weather_conditions','Driving_experience']).agg(
    Counts =('Driving_experience','count'),
))

# we can see in the second table that most of the road condition in dry condition even in normal weather conditions they would have the higher rate of accedints
display(df.groupby(['Weather_conditions','Road_surface_conditions']).agg(
    Counts =('Driving_experience','count'),
))

# There is no much fatal injuries in whatever the weather condition are. if they are exist they tend to be small number
display(df.groupby(['Weather_conditions','Accident_severity']).agg(
    Counts =('Driving_experience','count'),
))

# Sunday would be the safest day to have an accedint in all types of conditions
display(df.groupby(['Weather_conditions','Day_of_week']).agg(
    Counts =('Driving_experience','count'),
))

# Accedint occur more in driver between 18-50 years
display(df['Age_band_of_driver'].value_counts())

# Automobile vehicle tend to have accident more than any type of cars
display(df['Type_of_vehicle'].value_counts())

display(df['Number_of_vehicles_involved'].mean())
display(df['Number_of_casualties'].mean())
# Out:
#                                        Counts
# Weather_conditions Driving_experience
# Cloudy             1-2yr                   19
#                    2-5yr                   21
#                    5-10yr                  48
#                    Above 10yr              18
#                    Below 1yr               17
#                    No Licence               2
# Fog or mist        2-5yr                    2
#                    5-10yr                   5
#                    Above 10yr               3
# Normal             1-2yr                 1408
#                    2-5yr                 2155
#                    5-10yr                3439
#                    Above 10yr            1843
#                    Below 1yr             1100
#                    No Licence              93
#                    unknown                 25
# Other              1-2yr                   45
#                    2-5yr                   62
#                    5-10yr                 101
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(3, 3))
plt.hist(df['Number_of_vehicles_involved'])
plt.show()

plt.figure(figsize=(3, 3))
plt.hist(df['Number_of_casualties'])
plt.show()

# both numerical values tend to have skewed to the left distribution

plt.figure(figsize=(5, 5))
plt.hist(df['Weather_conditions'].value_counts().index, weights=df['Weather_conditions'].value_counts())
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(5, 5))
plt.hist(df['Road_surface_conditions'].value_counts().index, weights=df['Road_surface_conditions'].value_counts())
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(5, 5))
plt.hist(df['Driving_experience'].value_counts().index, weights=df['Driving_experience'].value_counts())
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(5, 5))
plt.hist(df['Accident_severity'].value_counts().index, weights=df['Accident_severity'].value_counts())
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(5, 5))
plt.hist(df['Day_of_week'].value_counts().index, weights=df['Day_of_week'].value_counts())
plt.xticks(rotation=90)
plt.show()

# we can see in which weather condition, road condition, driving experience, accident severity, and day of the week they have the highest accidents

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
from sklearn.preprocessing import LabelEncoder


Encoded_df = df.copy()

# Creating encoded value for correlation *correlation just accept numerical values*
for i in Encoded_df.select_dtypes(include='object').columns:
  le = LabelEncoder()
  Encoded_df[i] = le.fit_transform(Encoded_df[i])

display(Encoded_df.corr())

display(df.select_dtypes(exclude='object').corr())

# Result both of them if needed
# Out:
#                                  Time  Day_of_week  Age_band_of_driver  \
# Time                         1.000000    -0.010448            0.001667
# Day_of_week                 -0.010448     1.000000            0.019993
# Age_band_of_driver           0.001667     0.019993            1.000000
# Sex_of_driver               -0.004116     0.009986           -0.351878
# Educational_level           -0.002210    -0.004517            0.013613
# Vehicle_driver_relation     -0.002559     0.003303           -0.005841
# Driving_experience          -0.009114    -0.010062           -0.013407
# Type_of_vehicle             -0.020400    -0.002417            0.004830
# Owner_of_vehicle            -0.001548     0.001417            0.005405
# Area_accident_occured        0.001262     0.003281            0.011472
# Lanes_or_Medians             0.003731    -0.009320            0.008176
# Road_allignment             -0.003915    -0.008505            0.000486
# ...

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
plt.figure(figsize=(3, 3))
plt.hist(df['Number_of_vehicles_involved'])
plt.show()

plt.figure(figsize=(3, 3))
plt.hist(df['Number_of_casualties'])
plt.show()

plt.figure(figsize=(5, 5))
plt.barh(df['Weather_conditions'].value_counts().index, df['Weather_conditions'].value_counts().values)
plt.show()


plt.figure(figsize=(5, 5))
plt.barh(df['Day_of_week'].value_counts().index, df['Day_of_week'].value_counts().values)
plt.show()

plt.figure(figsize=(5, 5))
plt.barh(df['Road_surface_conditions'].value_counts().index, df['Road_surface_conditions'].value_counts().values)
plt.show()

plt.figure(figsize=(5, 5))
plt.barh(df['Driving_experience'].value_counts().index, df['Driving_experience'].value_counts().values)
plt.show()

plt.figure(figsize=(20, 20))
sns.heatmap(Encoded_df.corr(), annot=True)
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
# Casulaty_class
# Sex_of_casualty
# Age-band_of_casualty
# Casualty_severity

plt.figure(figsize=(5, 5))
plt.pie(df['Weather_conditions'].value_counts(), labels=df['Weather_conditions'].value_counts().index, autopct='%1.1f%%')
plt.show()

plt.figure(figsize=(5, 5))
plt.pie(df['Day_of_week'].value_counts(), labels=df['Day_of_week'].value_counts().index, autopct='%1.1f%%')
plt.show()

plt.figure(figsize=(5, 5))
plt.pie(df['Road_surface_conditions'].value_counts(), labels=df['Road_surface_conditions'].value_counts().index, autopct='%1.1f%%')
plt.show()

plt.figure(figsize=(5, 5))
plt.pie(df['Accident_severity'].value_counts(), labels=df['Accident_severity'].value_counts().index, autopct='%1.1f%%')
plt.show()

plt.figure(figsize=(5, 5))
plt.boxplot(df['Number_of_vehicles_involved'].value_counts())
plt.show()

plt.figure(figsize=(5, 5))
plt.boxplot(df['Number_of_casualties'].value_counts())
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
### Insights

# we can see in the first table that most of the driving experience in 5-10 years even in normal weather conditions they would have the higher rate of accedints

# we can see in the second table that most of the road condition in dry condition even in normal weather conditions they would have the higher rate of accedints

# There is no much fatal injuries in whatever the weather condition are. if they are exist they tend to be small number

# Sunday would be the safest day to have an accedint in all types of conditions

# Accedint occur more in driver between 18-50 years

# Automobile vehicle tend to have accident more than any type of cars

# both numerical values tend to have skewed to the left distribution

# we can see from the correlation of the heatmap that there is no correlation
# in most of the columns except Casulaty_class, Sex_of_casualty, Age-band_of_casualty
# , Casualty_severity columns. and it's highly postive correlated

# From the boxplot we can see that there is only one value in both numerical values are outliers
# and the calculation of the numerical values would depend on the values counts becuase the numbers are small even after the standard scaler


### Decisions

# Make warning especially in normal weather conditions becuase they tend to have more accidents
# Try to fix the problem in automobile cars to minimize the accidents
# Do seminar about driving recklessly especially for people between the ages of 18-50
# Warn people no to dry in wet weather condition becuase of slippery roads
# After 2 years from getting first driving license, start do some warning and needing to test driving skills due to increase of accidents after 2 years of getting the driving license rapidly
