# %% [markdown]
# #Data Visualization Tutorial

# %% [markdown]
# ##Introduction
# In this tutorial, you will learn to visualize data using various plots. We will use the "Car Crashes" dataset from Seaborn, which contains information on car crashes in the United States. You will perform different types of analyses such as univariate, bivariate, and multivariate analysis.

# %% [markdown]
# #1. Loading the Dataset

# %% [markdown]
# Instructions:
#
#
# *   Load the "Car Crashes" dataset from Seaborn.
# *   Print the first few rows to understand the structure of the data.

# %%
import seaborn as sns
import pandas as pd

# Load the dataset
df = sns.load_dataset('car_crashes')
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# #2. Univariate Analysis

# %% [markdown]
# ### Histogram
#
# Instructions:
#
# * Create a histogram to visualize the distribution of the 'total' crashes.
# * Use kde=True to add a kernel density estimate.
#
# Explanation:
# Univariate analysis involves examining the distribution of a single variable. The histogram helps visualize the frequency distribution of total crashes.

# %%
import matplotlib.pyplot as plt

# Histogram for total crashes
plt.figure(figsize=(10, 6))
sns.histplot(df['total'], kde=True, bins=20, color='blue')
plt.title('Histogram of Total Crashes')
plt.xlabel('Total Crashes')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ###Bar Chart
#
# Instructions:
#
# * Create a bar chart to compare average insurance premiums by state.
# * Rotate x-axis labels for better readability.
#
# Explanation:
# Bar charts are useful for comparing the average values of a single variable across different categories.

# %%
# Bar Chart for average insurance premium by state
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='abbrev', y='ins_premium', palette='muted')
plt.title('Average Insurance Premium by State')
plt.xlabel('State')
plt.ylabel('Average Insurance Premium')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 3. Bivariate Analysis

# %% [markdown]
# ###Scatter plot
#
# Instructions:
#
# * Create a scatter plot to visualize the relationship between 'speeding' and 'alcohol'.
# * Use different colors for each state using the 'abbrev' column.
#
# Explanation:
# Bivariate analysis examines the relationship between two variables. Scatter plots help identify correlations and trends between variables.

# %%
# Create a scatter plot to visualize the relationship between 'speeding' and 'alcohol'.
# write your code here

plt.figure(figsize=(10, 6))
scatter_plot = sns.scatterplot(data=df, x='speeding', y='alcohol', hue='abbrev', palette='viridis')
plt.xlabel('speeding Axis Label')
plt.ylabel('alcohol Axis Label')
plt.show()

# %% [markdown]
# ###HexBin
#
# Instructions:
# Create a HexBin plot to visualize the density of data points for 'speeding' and 'alcohol'.
#
# Explanation:
# HexBin plots are useful for visualizing the density of data points, especially for large datasets with overlapping points.

# %%
# Create a HexBin plot to visualize the density of data points for 'speeding' and 'alcohol'.
# write your code here
df.plot.hexbin(x='speeding',y='alcohol',gridsize=15)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %% [markdown]
# #4. Multivariate Analysis

# %% [markdown]
# ###Heatmap
#
# Instructions:
#
# * Calculate the correlation matrix for the dataset.
# * Create a heatmap to visualize the correlations between variables.
#
# Explanation:
# Multivariate analysis involves examining relationships between three or more variables. Heatmaps are excellent for visualizing correlation matrices.

# %%
# Calculate the correlation matrix for the dataset.
# write your code here
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['abbrev_encoded'] = label_encoder.fit_transform(df['abbrev'])

f = (
    df.loc[:,['total','speeding','alcohol','not_distracted','no_previous','ins_premium','ins_losses','abbrev_encoded']]
).corr()
display(f)

# Create a heatmap to visualize the correlations between variables.
# write your code here
sns.heatmap(f,annot=True)
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
# abbrev_encoded  0.043213  0.079701  0.135754        0.004800    -0.029075
#
#                 ins_premium  ins_losses  abbrev_encoded
# total             -0.199702   -0.036011        0.043213
# speeding          -0.077675   -0.065928        0.079701
# alcohol           -0.170612   -0.112547        0.135754
# not_distracted    -0.174856   -0.075970        0.004800
# ...

# %% [markdown]
# ###Pair Plot
#
# Instructions:
# Create a pair plot to visualize pairwise relationships and distributions for all numeric variables.
#
# Explanation:
# Pair plots provide a matrix of scatter plots and histograms, helping to identify relationships and distributions among multiple variables.

# %%
# Create a pair plot to visualize pairwise relationships and distributions for all numeric variables.
# write your code here
sns.pairplot(df)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# #5. Special Plots

# %% [markdown]
# ###Radar Chart
# Instructions:
#
# * Create a radar chart to compare 'speeding', 'alcohol', 'not_distracted', and 'no_previous' for a selected state.
# * Use polar coordinates for the chart.
#
# Explanation:
# Radar charts are useful for comparing multiple variables across a single category.

# %%
from math import pi

# Radar chart example
categories = ['speeding', 'alcohol', 'not_distracted', 'no_previous']
N = len(categories)

# Example data for a single state (e.g., Alabama)
values = df[df['abbrev'] == 'AL'][categories].values.flatten().tolist()
values += values[:1]

angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='red', alpha=0.25)
ax.plot(angles, values, color='red', linewidth=2)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)
plt.title('Radar Chart for Alabama')
plt.show()

# %% [markdown]
# ###Violin Plot
#
# Instructions:
#
# * Create a violin plot to visualize the distribution of total crashes by state.
# * Rotate x-axis labels for better readability.
#
# Explanation:
# Violin plots combine box plots and kernel density plots to show the distribution of data across different categories.

# %%
# Create a violin plot to visualize the distribution of total crashes by state.
# write your code here

# sns.violinplot(x='abbrev',y='total',data=df)
sns.violinplot(data=df['total'])
plt.xticks(rotation=90)
# Out:
# (array([0]), [Text(0, 0, '0')])

# %%
# All generated usig ChatGPT and few changes from me
# just an interactive plots for all the plots above with few problems
# to run you need to do the below commands run each one alone in the cell
# pip install --upgrade jupyterlab
# pip install --upgrade ipywidgets
# jupyter labextension update --all
# pip install ipywidgets
# pip install dash

import matplotlib.pyplot as plt
import numpy as np
from math import pi

# Create Dash app
app = dash.Dash(__name__)

app.layout = html.Div([
    html.Div([
        dcc.Dropdown(
            id='plot-type',
            options=[
                {'label': 'Bar Plot', 'value': 'bar'},
                {'label': 'Heatmap', 'value': 'heatmap'},
                {'label': 'Hexbin Plot', 'value': 'hexbin'},
                {'label': 'Histogram', 'value': 'histogram'},
                {'label': 'Pair Plot', 'value': 'pair'},
                {'label': 'Radar Chart', 'value': 'radar'},
                {'label': 'Scatter Plot', 'value': 'scatter'},
                {'label': 'Violin Plot', 'value': 'violin'},
            ],
            value='scatter',
            placeholder="Select a plot type"
        ),
        html.Div(id='additional-options')
    ], style={'background-color': '#f0f0f0', 'padding': '10px', 'border-radius': '5px'}),
    dcc.Dropdown(
        id='x-column',
        options=[{'label': col, 'value': col} for col in df.columns],
        value=df.columns[0],
        placeholder='Select X-axis column'
    ),
    dcc.Dropdown(
        id='y-column',
        options=[{'label': col, 'value': col} for col in df.columns],
        value=df.columns[1],
        placeholder='Select Y-axis column',
        style={'display': 'none'}
    ),
    dcc.Dropdown(
        id='color-column',
        options=[{'label': col, 'value': col} for col in df.columns],
        value=None,
        placeholder='Select Color column',
        style={'display': 'none'}
    ),
    dcc.Input(
        id='nbins',
        type='number',
        value=30,
        min=1,
        step=1,
        style={'display': 'none'}
    ),
    dcc.Checklist(
        id='kde',
        options=[{'label': 'Kernel Density Estimate', 'value': 'kde'}],
        value=[],
        style={'display': 'none'}
    ),
    dcc.RadioItems(
        id='violin-option',
        options=[
            {'label': 'One Column', 'value': 'one'},
            {'label': 'Two Columns', 'value': 'two'}
        ],
        value='one',
        labelStyle={'display': 'inline-block', 'margin-right': '10px'},
        style={'display': 'none'}
    ),
    dcc.RadioItems(
        id='bar-option',
        options=[
            {'label': 'One Column', 'value': 'one'},
            {'label': 'Two Columns', 'value': 'two'}
        ],
        value='one',
        labelStyle={'display': 'inline-block', 'margin-right': '10px'},
        style={'display': 'none'}
    ),
    dcc.Input(
        id='num-categories',
        type='number',
        value=3,
        min=2,
        max=len(df.columns),
        step=1,
        style={'display': 'none'}
    ),
    dcc.Dropdown(
        id='category-selector',
        options=[{'label': col, 'value': col} for col in df.columns if col != 'abbrev'],
        value=['speeding', 'alcohol', 'not_distracted', 'no_previous'],
        multi=True,
        placeholder='Select categories for radar chart',
        style={'display': 'none'}
    ),
    dcc.Graph(id='plot')
])

@app.callback(
    [dash.dependencies.Output('plot', 'figure'),
     dash.dependencies.Output('y-column', 'style'),
     dash.dependencies.Output('color-column', 'style'),
     dash.dependencies.Output('nbins', 'style'),
     dash.dependencies.Output('kde', 'style'),
     dash.dependencies.Output('violin-option', 'style'),
     dash.dependencies.Output('bar-option', 'style'),
     dash.dependencies.Output('num-categories', 'style'),
     dash.dependencies.Output('category-selector', 'style')],
    [dash.dependencies.Input('plot-type', 'value'),
     dash.dependencies.Input('x-column', 'value'),
     dash.dependencies.Input('y-column', 'value'),
     dash.dependencies.Input('color-column', 'value'),
     dash.dependencies.Input('nbins', 'value'),
     dash.dependencies.Input('kde', 'value'),
     dash.dependencies.Input('violin-option', 'value'),
     dash.dependencies.Input('bar-option', 'value'),
     dash.dependencies.Input('num-categories', 'value'),
     dash.dependencies.Input('category-selector', 'value')]
)
def update_plot(plot_type, x_column, y_column, color_column, nbins, kde, violin_option, bar_option, num_categories, selected_categories):
    if plot_type == 'scatter':
        fig = px.scatter(df, x=x_column, y=y_column, color=color_column)
        y_column_style = {'display': 'block'}
        color_column_style = {'display': 'block'}
        nbins_style = {'display': 'none'}
        kde_style = {'display': 'none'}
        violin_option_style = {'display': 'none'}
        bar_option_style = {'display': 'none'}
        num_categories_style = {'display': 'none'}
        category_selector_style = {'display': 'none'}
    elif plot_type == 'bar':
        if bar_option == 'one':
            fig = px.bar(df, x=x_column, color=x_column)
        else:
            fig = px.bar(df, x=x_column, y=y_column, color=y_column)
        y_column_style = {'display': 'block'} if bar_option == 'two' else {'display': 'none'}
        color_column_style = {'display': 'none'}
        nbins_style = {'display': 'none'}
        kde_style = {'display': 'none'}
        violin_option_style = {'display': 'none'}
        bar_option_style = {'display': 'block'}
        num_categories_style = {'display': 'none'}
        category_selector_style = {'display': 'none'}
    elif plot_type == 'violin':
        if violin_option == 'one':
            fig = px.violin(df, x=x_column, box=True, points='all')
        else:
            fig = px.violin(df, x=x_column, y=y_column, box=True, points='all')
        y_column_style = {'display': 'block'} if violin_option == 'two' else {'display': 'none'}
        color_column_style = {'display': 'none'}
        nbins_style = {'display': 'none'}
        kde_style = {'display': 'none'}
        violin_option_style = {'display': 'block'}
        bar_option_style = {'display': 'none'}
        num_categories_style = {'display': 'none'}
        category_selector_style = {'display': 'none'}
    elif plot_type == 'histogram':
        fig = px.histogram(df, x=x_column, nbins=nbins, opacity=0.7, title=f'Histogram of {x_column}')
        y_column_style = {'display': 'none'}
        color_column_style = {'display': 'none'}
        nbins_style = {'display': 'block'}
        kde_style = {'display': 'block'}
        violin_option_style = {'display': 'none'}
        bar_option_style = {'display': 'none'}
        num_categories_style = {'display': 'none'}
        category_selector_style = {'display': 'none'}
        
        # Calculate KDE if selected
        if 'kde' in kde:
            data = df[x_column].dropna()
            kde_estimator = stats.gaussian_kde(data, bw_method='scott')  # Adjust bandwidth method
            x = np.linspace(data.min(), data.max(), 1000)
            kde_y = kde_estimator(x)
            fig.add_trace(go.Scatter(
                x=x,
                y=kde_y * len(data) * (data.max() - data.min()) / nbins,  # Normalize KDE to match histogram
                mode='lines',
                name='KDE',
                line=dict(color='red', width=2)
            ))
    elif plot_type == 'hexbin':
        fig, ax = plt.subplots(figsize=(10, 8))  # Increase the figure size
        df.plot.hexbin(x=x_column, y=y_column, gridsize=nbins, ax=ax, cmap='viridis')
        buf = io.BytesIO()
        plt.savefig(buf, format='png', bbox_inches='tight')  # Save the figure with tight layout
        buf.seek(0)
        plt.close()
        encoded_image = base64.b64encode(buf.read()).decode('utf-8')
        fig = go.Figure()
        fig.add_layout_image(
            dict(
                source=f'data:image/png;base64,{encoded_image}',
                xref="paper",
                yref="paper",
                x=0,
                y=1,
                sizex=1,
                sizey=1,
                xanchor="left",
                yanchor="top"
            )
        )
        fig.update_layout(
            width=800,  # Adjust the width
            height=600,  # Adjust the height
            margin=dict(l=20, r=20, t=20, b=20)
        )
        fig.update_xaxes(visible=False, showticklabels=False)
        fig.update_yaxes(visible=False, showticklabels=False)
        y_column_style = {'display': 'block'}
        color_column_style = {'display': 'none'}
        nbins_style = {'display': 'block'}
        kde_style = {'display': 'none'}
        violin_option_style = {'display': 'none'}
        bar_option_style = {'display': 'none'}
        num_categories_style = {'display': 'none'}
        category_selector_style = {'display': 'none'}
    elif plot_type == 'heatmap':
        corr = df.loc[:, ['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous', 'ins_premium', 'ins_losses', 'abbrev_encoded']].corr()
        fig, ax = plt.subplots(figsize=(10, 8))  # Increase the figure size
        sns.heatmap(corr, annot=True, ax=ax, cmap='viridis')
        buf = io.BytesIO()
        plt.savefig(buf, format='png', bbox_inches='tight')  # Save the figure with tight layout
        buf.seek(0)
        plt.close()
        encoded_image = base64.b64encode(buf.read()).decode('utf-8')
        fig = go.Figure()
        fig.add_layout_image(
            dict(
                source=f'data:image/png;base64,{encoded_image}',
                xref="paper",
                yref="paper",
                x=0,
                y=1,
                sizex=1,
                sizey=1,
                xanchor="left",
                yanchor="top"
            )
        )
        fig.update_layout(
            width=800,  # Adjust the width
            height=600,  # Adjust the height
            margin=dict(l=20, r=20, t=20, b=20)
        )
        y_column_style = {'display': 'none'}
        color_column_style = {'display': 'none'}
        nbins_style = {'display': 'none'}
        kde_style = {'display': 'none'}
        violin_option_style = {'display': 'none'}
        bar_option_style = {'display': 'none'}
        num_categories_style = {'display': 'none'}
        category_selector_style = {'display': 'none'}
    elif plot_type == 'pair':
        sns.pairplot(df)
        buf = io.BytesIO()
        plt.savefig(buf, format='png', bbox_inches='tight')  # Save the figure with tight layout
        buf.seek(0)
        plt.close()
        encoded_image = base64.b64encode(buf.read()).decode('utf-8')
        fig = go.Figure()
        fig.add_layout_image(
            dict(
                source=f'data:image/png;base64,{encoded_image}',
                xref="paper",
                yref="paper",
                x=0,
                y=1,
                sizex=1,
                sizey=1,
                xanchor="left",
                yanchor="top"
            )
        )
        fig.update_layout(
            width=800,  # Adjust the width
            height=600,  # Adjust the height
            margin=dict(l=20, r=20, t=20, b=20)
        )
        y_column_style = {'display': 'none'}
        color_column_style = {'display': 'none'}
        nbins_style = {'display': 'none'}
        kde_style = {'display': 'none'}
        violin_option_style = {'display': 'none'}
        bar_option_style = {'display': 'none'}
        num_categories_style = {'display': 'none'}
        category_selector_style = {'display': 'none'}
    elif plot_type == 'radar':
        categories = selected_categories[:num_categories] if selected_categories else df.columns[:num_categories]
        N = len(categories)
        
        values = df[df['abbrev'] == 'AL'][categories].values.flatten().tolist()
        values += values[:1]

        angles = [n / float(N) * 2 * pi for n in range(N)]
        angles += angles[:1]

        fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
        ax.fill(angles, values, color='red', alpha=0.25)
        ax.plot(angles, values, color='red', linewidth=2)
        ax.set_yticklabels([])
        ax.set_xticks(angles[:-1])
        ax.set_xticklabels(categories)
        plt.title('Radar Chart for Alabama')
        buf = io.BytesIO()
        plt.savefig(buf, format='png', bbox_inches='tight')
        buf.seek(0)
        plt.close()
        encoded_image = base64.b64encode(buf.read()).decode('utf-8')
        fig = go.Figure()
        fig.add_layout_image(
            dict(
                source=f'data:image/png;base64,{encoded_image}',
                xref="paper",
                yref="paper",
                x=0,
                y=1,
                sizex=1,
                sizey=1,
                xanchor="left",
                yanchor="top"
            )
        )
        fig.update_layout(
            width=800,  # Adjust the width
            height=600,  # Adjust the height
            margin=dict(l=20, r=20, t=20, b=20)
        )
        y_column_style = {'display': 'none'}
        color_column_style = {'display': 'none'}
        nbins_style = {'display': 'none'}
        kde_style = {'display': 'none'}
        violin_option_style = {'display': 'none'}
        bar_option_style = {'display': 'none'}
        num_categories_style = {'display': 'block'}
        category_selector_style = {'display': 'block'}
    else:
        fig = px.scatter(df, x=x_column, y=y_column)
        y_column_style = {'display': 'block'}
        color_column_style = {'display': 'none'}
        nbins_style = {'display': 'none'}
        kde_style = {'display': 'none'}
        violin_option_style = {'display': 'none'}
        bar_option_style = {'display': 'none'}
        num_categories_style = {'display': 'none'}
        category_selector_style = {'display': 'none'}

    fig.update_layout(
        title=f'{plot_type.capitalize()} of {x_column} {"and " + y_column if y_column else ""}',
        xaxis_title=x_column,
        yaxis_title=y_column if y_column else 'Count'
    )
    
    return fig, y_column_style, color_column_style, nbins_style, kde_style, violin_option_style, bar_option_style, num_categories_style, category_selector_style

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 15
#      12 from math import pi
#      14 # Create Dash app
# ---> 15 app = dash.Dash(__name__)
#      17 app.layout = html.Div([
#      18     html.Div([
#      19         dcc.Dropdown(
#    (...)
#     107     dcc.Graph(id='plot')
#     108 ])
#     110 @app.callback(
#     111     [dash.dependencies.Output('plot', 'figure'),
#     112      dash.dependencies.Output('y-column', 'style'),
#    (...)
#     130 )
#     131 def update_plot(plot_type, x_column, y_column, color_column, nbins, kde, violin_option, bar_option, num_categories, selected_categories):
#
# NameError: name 'dash' is not defined
